# %%
# 初加载模型

import whisper
import os
import argparse
import torch
from pathlib import Path

whisper_size = "large-v2"

torch.cuda.empty_cache()
print('加载模型 Loading model...')
model = whisper.load_model(whisper_size)
print('加载完成')
# Out:
# 加载模型 Loading model...
# 加载完成

# %%
# 参数设置

# 语言
language = "japanese"

# 如果为 "真"，模型的前一个输出将作为下一个窗口的提示。
# 禁用可能会使不同窗口的文本不一致，但模型变得不容易
# 陷入失败循环，例如重复循环或时间戳不同步。
condition_on_previous_text = True

# %%
#运行Whisper/Run Whisper

import os
import time
from pathlib import Path
import torch

def save_srt(segments, output_path):
    with open(output_path, 'w', encoding='utf-8') as f:
        for i, segment in enumerate(segments):
            start = segment['start']
            end = segment['end']
            text = segment['text']
            
            # 格式化时间
            start_hours = int(start // 3600)
            start_minutes = int((start % 3600) // 60)
            start_seconds = int(start % 60)
            start_milliseconds = int((start - int(start)) * 1000)
            end_hours = int(end // 3600)
            end_minutes = int((end % 3600) // 60)
            end_seconds = int(end % 60)
            end_milliseconds = int((end - int(end)) * 1000)
            
            tm1 = f"{start_hours:02}:{start_minutes:02}:{start_seconds:02},{start_milliseconds:03} --> "
            tm2 = f"{end_hours:02}:{end_minutes:02}:{end_seconds:02},{end_milliseconds:03}"
            # 写入文件
            f.write(f"{i + 1}\n")
            f.write(f"{tm1}{tm2}\n")
            f.write(f"{text}\n\n")
            print(f"{tm1}{tm2}")
            print(text)


def process_files(upload_path, output_dir, model, language, condition_on_previous_text):
    for root, _, files in os.walk(upload_path):
        for file_name in files:
            if file_name.endswith(".wav"):
                file_path = os.path.join(root, file_name)
                rel_path = os.path.relpath(file_path, upload_path)
                srt_path = os.path.join(output_dir, os.path.splitext(rel_path)[0] + ".srt")
                os.makedirs(os.path.dirname(srt_path), exist_ok=True)
                
                print(f'{file_path} 识别中...')
                start_time = time.time()
                result = model.transcribe(
                    audio=file_path,
                    language=language,
                    condition_on_previous_text=condition_on_previous_text
                )
                end_time = time.time()
                processing_time = end_time - start_time
                print(f"{processing_time:.2f} seconds")
                
                save_srt(result["segments"], srt_path)
                print(f'{srt_path} 已保存 Saved')


upload_path = "./raw_audio/"
output_dir = "./srt/"

os.makedirs(output_dir, exist_ok=True)
# 处理文件
process_files(upload_path, output_dir, model, language, condition_on_previous_text)
torch.cuda.empty_cache()
print('字幕生成完毕')
# Out:
# ./raw_audio/Haliva/Haliva_3Daysaway.wav 识别中...
# 1.11 seconds
# 00:00:00,000 --> 00:00:05,280
# 主どこ行ってたの? 主がいなかったら
# 00:00:05,280 --> 00:00:09,080
# アラフは枯れちゃうよ
# ./srt/Haliva/Haliva_3Daysaway.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_7Daysaway.wav 识别中...
# 2.98 seconds
# 00:00:00,000 --> 00:00:04,320
# アラフね、すごく長い夢を見たの。
# 00:00:05,320 --> 00:00:19,519
# 夢の中で、主がどっか行っちゃって、大地も氷に覆われ、みんな消えてなくなって、アラフも冬眠し始めちゃって。
# 00:00:21,120 --> 00:00:28,000
# その時、運よく主の声が聞こえて、それで目が覚めたの。
# ./srt/Haliva/Haliva_7Daysaway.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_About_Haliva.wav 识别中...
# 1.68 seconds
# 00:00:00,000 --> 00:00:14,000
# もしもいつかアラフが大きくなって、本物の春の神様になったら、あの世界にも春をもたらしてあげることができたらいいのに。
# ./srt/Haliva/Haliva_About_Haliva.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_About_Others.wav 识别中...
# 3.15 seconds
# 00:00:00,000 --> 00:00:07,400
# フィロドーシお姉ちゃん? アラフの方がお姉ちゃんなのに
# 00:00:07,400 --> 00:00:14,679
# だってアラフの方がずっと先に主と出会えているのだから
# 00:00:14,679 --> 00:00:19,839
# でも確かに フィロドーシお姉ちゃんの方が
# 00:00:19,839 --> 00:00:25,160
# アラフよりもずっと体が大きいの
# 00:00:25,160 --> 00:00:29,960
# うううう アラフわかんない
# ./srt/Haliva/Haliva_About_Others.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_About_Special.wav 识别中...
# 4.38 seconds
# 00:00:00,000 --> 00:00:04,000
# アラフはね、夕べ夢を見たの。
# 00:00:04,700 --> 00:00:13,000
# 春の神様が、神々の楽園で、ずっとアラフに向かって何かを話していた。
# 00:00:13,500 --> 00:00:22,000
# でもアラフは人間界にいるから、春の神様が何て言っていたか聞き取れなかったの。
# 00:00:22,500 --> 00:00:30,000
# それでね、春の神様が手を振ってくれて、遠いどこかを指さしてね、
# 00:00:30,500 --> 00:00:36,000
# そしてアラフが振り向いたら、そこに主が見えたの。
# ./srt/Haliva/Haliva_About_Special.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_About_World.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:07,400
# 温かな太陽、柔らかな雨、春夏秋冬という名の式。
# 00:00:08,900 --> 00:00:11,400
# アラフはここが大好きなの。
# ./srt/Haliva/Haliva_About_World.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Chat.wav 识别中...
# 1.45 seconds
# 00:00:00,000 --> 00:00:04,560
# どんな木材ならこんな素敵なお椀ができるの?
# 00:00:05,520 --> 00:00:09,599
# アラフは主とお揃いのお椀が使いたいの
# ./srt/Haliva/Haliva_After_Marriage_Chat.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Festival.wav 识别中...
# 2.04 seconds
# 00:00:00,000 --> 00:00:06,000
# アラフはね、祝日の意味がだんだんわかってきた気がするの。
# 00:00:07,000 --> 00:00:15,000
# どんな祝日も、ちゃんと大切で大好きな人と一緒に過ごさないとダメなの。
# ./srt/Haliva/Haliva_After_Marriage_Festival.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Fondle.wav 识别中...
# 1.03 seconds
# 00:00:00,000 --> 00:00:02,000
# えへへ…
# 00:00:02,800 --> 00:00:04,799
# なんでたかわらふ…
# 00:00:05,299 --> 00:00:07,299
# すこしはずかしいよ…
# ./srt/Haliva/Haliva_After_Marriage_Fondle.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Gift.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:02,000
# プレゼントだ!
# 00:00:02,000 --> 00:00:07,000
# 今日はアラフも主のためにプレゼントを用意してきたよ
# 00:00:07,000 --> 00:00:09,000
# えへへ
# ./srt/Haliva/Haliva_After_Marriage_Gift.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Greet.wav 识别中...
# 16.10 seconds
# 00:00:00,000 --> 00:00:03,200
# うーうーうーうーうー
# 00:00:04,040 --> 00:00:04,879
# 主!
# 00:00:05,540 --> 00:00:13,160
# アラフはね、恋の気持ちで歌を歌うことがどういうものかわかってきた気がするの
# 00:00:14,359 --> 00:00:21,580
# そしてアラフは今、マイロードの偉大なる名前で絶賛創作中なの
# ./srt/Haliva/Haliva_After_Marriage_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_After_Marriage_Touch.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:10,000
# マイロードに力と温もりを注ぎ込まれたアラフは、きっとすぐに大きくなれるね。
# ./srt/Haliva/Haliva_After_Marriage_Touch.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Amazed.wav 识别中...
# 2.75 seconds
# 00:00:00,000 --> 00:00:06,459
# ん、ん、ん?
# ./srt/Haliva/Haliva_Amazed.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Attack.wav 识别中...
# 0.82 seconds
# 00:00:00,000 --> 00:00:07,000
# マイロードの望みは このアラフが叶えてみせる
# ./srt/Haliva/Haliva_Attack.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Brithday_Greet.wav 识别中...
# 3.27 seconds
# 00:00:00,000 --> 00:00:03,680
# 今日はアラフの誕生日なんだって
# 00:00:03,680 --> 00:00:10,880
# アラフのことを植えてくれたのは主だから 人間同士の呼び方だと
# 00:00:10,880 --> 00:00:20,679
# アラフは主のことをママ それともパパって呼んだ方がいいのかな
# 00:00:20,679 --> 00:00:29,600
# 神々の楽園ではそういう呼び方がなかったから よくわかんない
# 00:00:29,600 --> 00:00:33,679
# 主でいいと思うの
# ./srt/Haliva/Haliva_Brithday_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_01.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:03,000
# 春は万物がよみがえる季節
# 00:00:04,000 --> 00:00:08,000
# 草が芽吹き、花が咲き誇る季節
# ./srt/Haliva/Haliva_Chat_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_02.wav 识别中...
# 1.86 seconds
# 00:00:00,000 --> 00:00:06,679
# 夏は炎のような季節 水の中で泳いだり
# 00:00:06,679 --> 00:00:13,919
# アイスクリームとかアイスクリームとか食べ放題の季節 うわぁ
# 00:00:13,919 --> 00:00:17,400
# 今すぐ食べたい
# ./srt/Haliva/Haliva_Chat_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_03.wav 识别中...
# 2.29 seconds
# 00:00:00,000 --> 00:00:02,399
# 秋は根じきの季節。
# 00:00:03,560 --> 00:00:06,080
# 人間たちが実りを得て、
# 00:00:06,520 --> 00:00:08,839
# 木々が落葉する季節。
# 00:00:10,720 --> 00:00:14,720
# アラフの頭のてっぺんの葉っぱが落ちてこないか、
# 00:00:15,000 --> 00:00:16,800
# 気が切れないけど。
# ./srt/Haliva/Haliva_Chat_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_04.wav 识别中...
# 2.17 seconds
# 00:00:00,000 --> 00:00:02,000
# 冬は寒い季節
# 00:00:03,320 --> 00:00:06,679
# 夜がすごく長くなるけど大丈夫
# 00:00:07,540 --> 00:00:09,540
# 明けない夜はない
# 00:00:09,839 --> 00:00:11,839
# 春もいつか訪れる
# 00:00:13,359 --> 00:00:15,640
# そして一番大事なのは
# 00:00:16,600 --> 00:00:21,080
# 今回は主がアラフのそばにいてくれること
# ./srt/Haliva/Haliva_Chat_04.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_05.wav 识别中...
# 2.18 seconds
# 00:00:00,000 --> 00:00:05,719
# アラフ、本当に主と一緒に四季を巡ることができた。
# 00:00:06,900 --> 00:00:15,560
# これからも数え切れないほどの四季を歩んでいくんだって思うだけで、幸せな気分。
# 00:00:16,120 --> 00:00:18,120
# えへへへ。
# ./srt/Haliva/Haliva_Chat_05.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Chat_06.wav 识别中...
# 1.52 seconds
# 00:00:00,000 --> 00:00:02,680
# 髪を溶かすときは気をつけて
# 00:00:03,760 --> 00:00:07,320
# 落ちちゃった葉っぱがもう一度生えてくるの
# 00:00:07,679 --> 00:00:10,120
# すごく時間かかるんだから
# ./srt/Haliva/Haliva_Chat_06.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Christmas_Gift_01.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:05,000
# あれ? 主がサンタさんだったの?
# 00:00:05,000 --> 00:00:09,000
# なんと偉大なマイロード!
# ./srt/Haliva/Haliva_Christmas_Gift_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Christmas_Greet.wav 识别中...
# 1.56 seconds
# 00:00:00,000 --> 00:00:02,000
# メリークリスマス
# 00:00:02,800 --> 00:00:04,000
# マイロード
# 00:00:04,600 --> 00:00:10,000
# アラフと一緒にサンタさんが来るのを待っていましょう
# ./srt/Haliva/Haliva_Christmas_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dating_Accept.wav 识别中...
# 0.81 seconds
# 00:00:00,000 --> 00:00:04,000
# おでかけー おでかけー 楽しいの!
# ./srt/Haliva/Haliva_Dating_Accept.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dating_Refuse.wav 识别中...
# 0.70 seconds
# 00:00:00,000 --> 00:00:03,000
# アラフは今出かけたくないの
# ./srt/Haliva/Haliva_Dating_Refuse.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dead.wav 识别中...
# 1.01 seconds
# 00:00:00,000 --> 00:00:04,400
# すでに春をこの目で見たアラフは
# 00:00:04,400 --> 00:00:08,720
# もう絶望なんてしないの
# ./srt/Haliva/Haliva_Dead.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Defeat.wav 识别中...
# 0.84 seconds
# 00:00:00,000 --> 00:00:07,480
# う、うぅ……ごめんなさい、アラフ大失敗……
# ./srt/Haliva/Haliva_Defeat.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_01.wav 识别中...
# 1.20 seconds
# 00:00:00,000 --> 00:00:05,719
# 明るい春の日差しは、主に朝の挨拶を運んできたの。
# 00:00:06,440 --> 00:00:07,400
# おはよう。
# ./srt/Haliva/Haliva_Dress1_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_02.wav 识别中...
# 1.06 seconds
# 00:00:00,000 --> 00:00:10,240
# 春の日差しは一番美しい 半透明の金色に染まった希望のようなの
# ./srt/Haliva/Haliva_Dress1_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_03.wav 识别中...
# 0.89 seconds
# 00:00:00,000 --> 00:00:03,000
# 明日は今日より暖かくなるわ
# 00:00:04,000 --> 00:00:07,000
# 春が訪れたからかな
# ./srt/Haliva/Haliva_Dress1_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_04.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:05,520
# アラフはこの春で一番美しい景色を集めてきたの
# 00:00:06,400 --> 00:00:08,720
# 全部主に送ってあげる
# ./srt/Haliva/Haliva_Dress1_04.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_05.wav 识别中...
# 1.17 seconds
# 00:00:00,000 --> 00:00:08,320
# 春だけじゃなくて、どの季節もアラフはこうやって主と手を繋いでいたいの。
# ./srt/Haliva/Haliva_Dress1_05.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_06.wav 识别中...
# 0.90 seconds
# 00:00:00,000 --> 00:00:07,839
# アラフはこの手で主のすべての願いを叶えてあげる
# ./srt/Haliva/Haliva_Dress1_06.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_07.wav 识别中...
# 0.71 seconds
# 00:00:00,000 --> 00:00:07,560
# 春は恋の芽生えも表しているのかな
# ./srt/Haliva/Haliva_Dress1_07.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_08.wav 识别中...
# 1.26 seconds
# 00:00:00,000 --> 00:00:07,560
# すべての春の神様がみんな大人になれるわけじゃないんだね
# 00:00:07,560 --> 00:00:12,679
# それでもアラフは頑張るから
# ./srt/Haliva/Haliva_Dress1_08.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_09.wav 识别中...
# 1.56 seconds
# 00:00:00,000 --> 00:00:06,839
# 花が咲き誇り 万物は容器に包まれている
# 00:00:06,839 --> 00:00:14,880
# アラフの心の中にも一つだけ秘密が育まれているわ
# ./srt/Haliva/Haliva_Dress1_09.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Dress1_10.wav 识别中...
# 0.94 seconds
# 00:00:00,000 --> 00:00:03,060
# アラフは春の神様になったの
# 00:00:04,200 --> 00:00:07,860
# 主だけの春の神様だよ
# ./srt/Haliva/Haliva_Dress1_10.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Duty.wav 识别中...
# 1.13 seconds
# 00:00:00,000 --> 00:00:04,679
# わかった アラフにどんどんまかせて
# 00:00:04,679 --> 00:00:09,400
# フリージアにやり方を教わったから
# ./srt/Haliva/Haliva_Duty.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Evening_Night_Greet_01.wav 识别中...
# 1.53 seconds
# 00:00:00,000 --> 00:00:04,000
# 主、主がやっと帰ってきた!
# 00:00:04,600 --> 00:00:14,000
# えへへ、アラフはね、玄関口で主が帰ってくるのずっと待ってたの。
# ./srt/Haliva/Haliva_Evening_Night_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Evening_Night_Greet_02.wav 识别中...
# 0.89 seconds
# 00:00:00,000 --> 00:00:02,000
# お腹ペコペコ
# 00:00:03,600 --> 00:00:04,600
# えへへ
# 00:00:05,500 --> 00:00:07,000
# ご飯はまだ?
# ./srt/Haliva/Haliva_Evening_Night_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Evening_Night_Greet_03.wav 识别中...
# 1.59 seconds
# 00:00:00,000 --> 00:00:06,719
# 暗くて静かになってきたね あの時みたいに
# 00:00:06,719 --> 00:00:13,040
# でも 今は主がいてくれているからちっとも寒くないの
# 00:00:13,040 --> 00:00:15,839
# いひひひ
# ./srt/Haliva/Haliva_Evening_Night_Greet_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Favor_Up.wav 识别中...
# 0.92 seconds
# 00:00:00,000 --> 00:00:07,000
# アラフ、どんどん主のことを好きになっていく。えへへ
# ./srt/Haliva/Haliva_Favor_Up.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Favorite.wav 识别中...
# 1.22 seconds
# 00:00:00,000 --> 00:00:04,639
# 太陽も、風も、雨も、みんな大好き!
# 00:00:05,600 --> 00:00:08,800
# この子たちのいる春は、もっと好き!
# ./srt/Haliva/Haliva_Favorite.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Firstmeeting.wav 识别中...
# 3.38 seconds
# 00:00:00,000 --> 00:00:07,799
# 伝説によれば、愛とぬくもりを運ぶ希望の芽は、春にしか出ないんだって。
# 00:00:09,040 --> 00:00:15,200
# アラフがもう一度芽吹いたのも、きっと春の訪れを示しているの。
# 00:00:16,800 --> 00:00:22,600
# だからマイロードは、その手でアラフを植え、水をくれた人。
# 00:00:24,080 --> 00:00:28,080
# 今度は、アラフに式を見せてください。
# ./srt/Haliva/Haliva_Firstmeeting.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Dislike_01.wav 识别中...
# 0.55 seconds
# 00:00:00,000 --> 00:00:02,000
# これ味しないから
# 00:00:02,680 --> 00:00:03,399
# 嫌い
# ./srt/Haliva/Haliva_Food_Dislike_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Dislike_02.wav 识别中...
# 1.08 seconds
# 00:00:00,000 --> 00:00:07,280
# 雪お姉ちゃんに渡して凍らせてもらえば、アイスクリームになるのかな?
# ./srt/Haliva/Haliva_Food_Dislike_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Like_01.wav 识别中...
# 0.94 seconds
# 00:00:00,000 --> 00:00:02,000
# アイスクリームだ!
# 00:00:03,000 --> 00:00:07,000
# 今ちょうど食べたいと思っているところなの!
# ./srt/Haliva/Haliva_Food_Like_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Like_02.wav 识别中...
# 0.90 seconds
# 00:00:00,000 --> 00:00:02,760
# 偉大なるアイスクリームの神
# 00:00:03,640 --> 00:00:05,639
# すなわちマイロード
# ./srt/Haliva/Haliva_Food_Like_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Midlike_02.wav 识别中...
# 0.77 seconds
# 00:00:00,000 --> 00:00:02,000
# いいにおい
# 00:00:02,919 --> 00:00:04,400
# さあ、主
# 00:00:04,639 --> 00:00:06,640
# 一緒に食べよ
# ./srt/Haliva/Haliva_Food_Midlike_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Midlike_03.wav 识别中...
# 1.37 seconds
# 00:00:00,000 --> 00:00:07,560
# アラフに毎日の糧を授けてくれたマイロードに感謝を
# 00:00:07,560 --> 00:00:12,679
# お腹いっぱい食べさせてくれてありがとう
# ./srt/Haliva/Haliva_Food_Midlike_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Midlike_04.wav 识别中...
# 1.92 seconds
# 00:00:00,000 --> 00:00:06,679
# アラフは水やりさえしてくれれば大きくなれるはずなんだけど
# 00:00:06,679 --> 00:00:11,880
# なんで食べ物も食べないといけないのかなぁ
# 00:00:11,880 --> 00:00:18,960
# アラフわかんない けど一応食べとこ
# ./srt/Haliva/Haliva_Food_Midlike_04.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Special_01.wav 识别中...
# 1.15 seconds
# 00:00:00,000 --> 00:00:07,280
# 魚の骨が喉に刺さったら痛いから、ゆっくりと慎重に食べないと。
# ./srt/Haliva/Haliva_Food_Special_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Food_Special_02.wav 识别中...
# 1.39 seconds
# 00:00:00,000 --> 00:00:09,800
# うぅー、冷たい。冷たいところは一緒なのに、なんでアイスクリームの方がずっと美味しいのかなぁ?
# ./srt/Haliva/Haliva_Food_Special_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Gift_Brithday.wav 识别中...
# 2.37 seconds
# 00:00:00,000 --> 00:00:03,320
# アラフの誕生日を祝ってくれてるの?
# 00:00:04,879 --> 00:00:05,879
# わぁ…
# 00:00:06,879 --> 00:00:09,300
# こんなに大きなケーキ…
# 00:00:10,359 --> 00:00:11,359
# 嬉しい!
# 00:00:12,359 --> 00:00:14,800
# くんくん、いい匂い…
# 00:00:15,679 --> 00:00:19,839
# 主、みんなも呼んできて一緒に食べよう!
# ./srt/Haliva/Haliva_Gift_Brithday.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Gift_Dislike.wav 识别中...
# 1.22 seconds
# 00:00:00,000 --> 00:00:02,000
# うーん…
# 00:00:02,399 --> 00:00:10,000
# 主、これを売ってお金に変えて、アイスクリームを買いに行こうよ。
# ./srt/Haliva/Haliva_Gift_Dislike.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Gift_Like.wav 识别中...
# 1.48 seconds
# 00:00:00,000 --> 00:00:02,560
# わーい!プレゼントだ!
# 00:00:03,060 --> 00:00:04,660
# アラフ気に入った!
# 00:00:05,100 --> 00:00:06,740
# 主ありがとう!
# 00:00:07,440 --> 00:00:10,140
# 偉大なるマイロードに賛美を!
# ./srt/Haliva/Haliva_Gift_Like.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Gift_Midlike.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:03,419
# アラフがいっぱいプレゼントもらっちゃったのは
# 00:00:04,259 --> 00:00:08,339
# 主がアラフのことが大好きだからでしょ?
# ./srt/Haliva/Haliva_Gift_Midlike.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Hate.wav 识别中...
# 1.86 seconds
# 00:00:00,000 --> 00:00:02,000
# 嫌いなもの?
# 00:00:03,000 --> 00:00:06,000
# アラフは寒いのは嫌いだけど…
# 00:00:07,000 --> 00:00:09,000
# 冬は嫌いじゃないの
# 00:00:10,000 --> 00:00:14,000
# だって、終わらない冬はないんだから
# 00:00:14,000 --> 00:00:16,000
# いひひひ
# ./srt/Haliva/Haliva_Hate.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Hurt.wav 识别中...
# 0.47 seconds
# 00:00:00,000 --> 00:00:02,000
# はっ! 主!
# ./srt/Haliva/Haliva_Hurt.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Mad.wav 识别中...
# 0.35 seconds
# 00:00:00,000 --> 00:00:02,000
# あるじ
# ./srt/Haliva/Haliva_Mad.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Newstory.wav 识别中...
# 0.96 seconds
# 00:00:00,000 --> 00:00:02,800
# 外で何が起きているのかな?
# 00:00:03,800 --> 00:00:05,799
# 季節の変わり目かな?
# ./srt/Haliva/Haliva_Newstory.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Palyer_Brithday_Greet.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:02,000
# 今日は素晴らしい日!
# 00:00:02,500 --> 00:00:04,500
# マイロードの誕生日!
# 00:00:05,400 --> 00:00:08,500
# 主、お誕生日おめでとう!
# ./srt/Haliva/Haliva_Palyer_Brithday_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Qixi_Gift_01.wav 识别中...
# 1.97 seconds
# 00:00:00,000 --> 00:00:04,320
# アラフは今、星々に願い事をしたの。
# 00:00:05,639 --> 00:00:11,160
# もっと主がアラフのことを好きになりますようにって。
# 00:00:12,400 --> 00:00:16,039
# こんなに早く実現するとは思わなかった。
# 00:00:16,519 --> 00:00:17,640
# えへへへ。
# ./srt/Haliva/Haliva_Qixi_Gift_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Qixi_Greet.wav 识别中...
# 1.49 seconds
# 00:00:00,000 --> 00:00:06,400
# 織姫様が空から彦星様のところにやってきた
# 00:00:06,400 --> 00:00:14,880
# アラフが神々の楽園から主のところにやってきたのと同じ感じ?
# ./srt/Haliva/Haliva_Qixi_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Midnight_Greet_01.wav 识别中...
# 1.61 seconds
# 00:00:00,000 --> 00:00:09,400
# 雨が降ったら家の中に入ること 雨に降られたら病気になるから
# 00:00:09,919 --> 00:00:18,080
# 主? アラフは今日は外で雨に降られてきてないよ
# ./srt/Haliva/Haliva_Rainy_Midnight_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Midnight_Greet_02.wav 识别中...
# 1.74 seconds
# 00:00:00,000 --> 00:00:03,280
# ぽつり ぽつり
# 00:00:03,280 --> 00:00:07,719
# アラフはねえ 今雨粒を数えてるの
# 00:00:07,719 --> 00:00:14,320
# やり方はルリに教わったの 主も一緒に数える?
# ./srt/Haliva/Haliva_Rainy_Midnight_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Morning_Greet_01.wav 识别中...
# 1.26 seconds
# 00:00:00,000 --> 00:00:03,640
# 雪じゃなくて…水の玉?
# 00:00:04,600 --> 00:00:05,600
# ねえ、見て!
# 00:00:06,000 --> 00:00:08,500
# 空から水の玉が落ちてきてるよ!
# ./srt/Haliva/Haliva_Rainy_Morning_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Morning_Greet_02.wav 识别中...
# 1.42 seconds
# 00:00:00,000 --> 00:00:03,640
# こ、こ、え、くしゃー!
# 00:00:03,640 --> 00:00:08,160
# ううう、ちょっと寒いー。
# 00:00:08,160 --> 00:00:14,560
# 雨の時の空気って、なんだかいつもと違うね。
# ./srt/Haliva/Haliva_Rainy_Morning_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Night_Greet_01.wav 识别中...
# 1.16 seconds
# 00:00:00,000 --> 00:00:04,839
# あれ? アラフはここにいちゃダメ?
# 00:00:04,839 --> 00:00:10,240
# 雨が降ったらすぐ家に帰るべき?
# ./srt/Haliva/Haliva_Rainy_Night_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Night_Greet_02.wav 识别中...
# 0.98 seconds
# 00:00:00,000 --> 00:00:04,679
# また雨が… 防がないと…
# 00:00:04,679 --> 00:00:11,400
# いや、ここは主のために雨を防ぐの
# ./srt/Haliva/Haliva_Rainy_Night_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Noon_Greet_01.wav 识别中...
# 0.99 seconds
# 00:00:00,000 --> 00:00:02,500
# これは雨って言うんでしょ?
# 00:00:03,240 --> 00:00:06,240
# さっき雪お姉ちゃんが教えてくれたの
# ./srt/Haliva/Haliva_Rainy_Noon_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Noon_Greet_02.wav 识别中...
# 2.19 seconds
# 00:00:00,000 --> 00:00:09,660
# アラフは雨水では成長できないらしいから、ちゃんと主がこのお椀を使って水やりをしてくれないと…
# 00:00:10,980 --> 00:00:18,339
# いや、アラフはもう水やりをしてもらわなくたって平気になったんだっけ?
# ./srt/Haliva/Haliva_Rainy_Noon_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Weekend_Greet_01.wav 识别中...
# 1.59 seconds
# 00:00:00,000 --> 00:00:04,259
# 今日も雨だから、お外に行っちゃダメって。
# 00:00:05,780 --> 00:00:13,140
# ふぅ、前に雪が降っている時は、一緒にお出かけしてたのに。
# ./srt/Haliva/Haliva_Rainy_Weekend_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Rainy_Weekend_Greet_02.wav 识别中...
# 1.79 seconds
# 00:00:00,000 --> 00:00:08,839
# 最近ずっと雨が降ってて 庭にあった大きな木の下にキノコが生えてきたの
# 00:00:08,839 --> 00:00:15,160
# アラフも頭の上にキノコが生えてきちゃうのかな
# ./srt/Haliva/Haliva_Rainy_Weekend_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Receive_Mail.wav 识别中...
# 0.79 seconds
# 00:00:00,000 --> 00:00:05,000
# 主、使いの者が手紙を届けてくれたの。
# ./srt/Haliva/Haliva_Receive_Mail.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Receive_Message.wav 识别中...
# 0.76 seconds
# 00:00:00,000 --> 00:00:05,000
# 主、ご友人様から手紙が届いてるよ。
# ./srt/Haliva/Haliva_Receive_Message.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sad.wav 识别中...
# 0.36 seconds
# 00:00:00,000 --> 00:00:02,000
# おるじ
# ./srt/Haliva/Haliva_Sad.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Shy.wav 识别中...
# 0.35 seconds
# 00:00:00,000 --> 00:00:02,000
# あるし
# ./srt/Haliva/Haliva_Shy.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_01.wav 识别中...
# 0.31 seconds
# 00:00:00,000 --> 00:00:00,500
# うん!
# ./srt/Haliva/Haliva_Skill_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_01_01.wav 识别中...
# 0.88 seconds
# 00:00:00,000 --> 00:00:07,879
# 春の神は言ってた 生存競争に情けはいらないって
# ./srt/Haliva/Haliva_Skill_01_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_01_02.wav 识别中...
# 0.79 seconds
# 00:00:00,000 --> 00:00:04,839
# 大切なものは、それ相応の力がないと守れない!
# ./srt/Haliva/Haliva_Skill_01_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_02.wav 识别中...
# 0.33 seconds
# 00:00:00,000 --> 00:00:02,000
# わかった
# ./srt/Haliva/Haliva_Skill_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_02_01.wav 识别中...
# 1.15 seconds
# 00:00:00,000 --> 00:00:08,000
# 希望の春が訪れるまで、命はみんなこの冬の寒さに耐えなければいけない。
# ./srt/Haliva/Haliva_Skill_02_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_02_02.wav 识别中...
# 1.17 seconds
# 00:00:00,000 --> 00:00:02,560
# マイロードが望む世界のため
# 00:00:03,359 --> 00:00:04,099
# そして
# 00:00:05,060 --> 00:00:07,060
# 主と共に歩んできた
# 00:00:07,440 --> 00:00:08,820
# この四季のため
# ./srt/Haliva/Haliva_Skill_02_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Skill_03.wav 识别中...
# 0.43 seconds
# 00:00:00,000 --> 00:00:01,000
# ふぅふぅ
# ./srt/Haliva/Haliva_Skill_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_1.wav 识别中...
# 0.88 seconds
# 00:00:00,000 --> 00:00:06,000
# えへへ、アラフはね、本当はちっとも眠くないの。
# ./srt/Haliva/Haliva_sleep1_Segment_1.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_10.wav 识别中...
# 0.94 seconds
# 00:00:00,000 --> 00:00:08,000
# あ、違う違う、字を書くんだった。顔をくっつけてどうするの?
# ./srt/Haliva/Haliva_sleep1_Segment_10.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_11.wav 识别中...
# 1.81 seconds
# 00:00:00,000 --> 00:00:04,799
# じゃあ書くよ 最初はこう
# 00:00:04,799 --> 00:00:09,800
# 次はこう 難しいけど
# 00:00:09,800 --> 00:00:15,560
# 絶対に書き間違えたりしないの だってアラフ
# 00:00:15,560 --> 00:00:19,679
# この字いっぱい練習したもん
# ./srt/Haliva/Haliva_sleep1_Segment_11.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_12.wav 识别中...
# 1.43 seconds
# 00:00:00,000 --> 00:00:13,800
# 今まではこの言葉が何を意味しているのか漠然たしかわからなかったの だって意味が多すぎるもん
# ./srt/Haliva/Haliva_sleep1_Segment_12.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_13.wav 识别中...
# 1.30 seconds
# 00:00:00,000 --> 00:00:10,759
# 親とこの間の感情を指す時もあるし 友達同士の感情を表す時にも使われるの
# ./srt/Haliva/Haliva_sleep1_Segment_13.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_14.wav 识别中...
# 1.46 seconds
# 00:00:00,000 --> 00:00:05,000
# 恋人同士が約束するときに使ったり、
# 00:00:05,000 --> 00:00:11,000
# 物に対して、いいねって評価するときにも使えて。
# ./srt/Haliva/Haliva_sleep1_Segment_14.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_15.wav 识别中...
# 2.75 seconds
# 00:00:00,000 --> 00:00:03,000
# アラフ、わかんない。
# 00:00:04,000 --> 00:00:11,000
# アイスクリームを食べたいと思う気持ちと、晴れの日になった時の気持ちは、
# 00:00:11,000 --> 00:00:18,000
# 主と親しくなりたいと思う気持ちとは、全然違うのに、
# 00:00:18,000 --> 00:00:22,000
# なんで同じ文字が使われているのかな。
# ./srt/Haliva/Haliva_sleep1_Segment_15.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_16.wav 识别中...
# 1.46 seconds
# 00:00:00,000 --> 00:00:08,000
# だから考えて考えていっぱい考えたけど
# 00:00:08,000 --> 00:00:15,599
# 春の神様の記憶が頭に浮かんでくるほど考えたの
# ./srt/Haliva/Haliva_sleep1_Segment_16.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_17.wav 识别中...
# 1.99 seconds
# 00:00:00,000 --> 00:00:09,000
# 春の神様の記憶の中には、四季もあれば花や果実のこともあった。
# 00:00:09,000 --> 00:00:17,000
# 彼女はそのすべてに対して平等かつ穏やかな気持ちでいたの。
# ./srt/Haliva/Haliva_sleep1_Segment_17.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_18.wav 识别中...
# 1.77 seconds
# 00:00:00,000 --> 00:00:13,000
# 神々の楽園で神々が祭りを開催して一緒にぶどう酒を飲み交わしたり、いろんな美味しい食べ物を食べたりしていた。
# ./srt/Haliva/Haliva_sleep1_Segment_18.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_19.wav 识别中...
# 1.61 seconds
# 00:00:00,000 --> 00:00:14,000
# 春の神様はね、そんな神々にも平等で穏やかな視線を注ぎながら、食べ物の一つ一つを味わっていたの。
# ./srt/Haliva/Haliva_sleep1_Segment_19.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_2.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:10,000
# 前に長い時間寝すぎちゃったせいかも。だから今は寝るのがそんなに好きじゃなくて。
# ./srt/Haliva/Haliva_sleep1_Segment_2.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_20.wav 识别中...
# 1.66 seconds
# 00:00:00,000 --> 00:00:14,000
# 彼女にとって、この世にこれといって特別な味もなければ、その生涯においてもこれといって特別な瞬間もなかったの。
# ./srt/Haliva/Haliva_sleep1_Segment_20.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_21.wav 识别中...
# 1.21 seconds
# 00:00:00,000 --> 00:00:09,000
# それなのに、その記憶を受け継いだアラフは、なぜこうも違うんだろう。
# ./srt/Haliva/Haliva_sleep1_Segment_21.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_22.wav 识别中...
# 2.73 seconds
# 00:00:00,000 --> 00:00:06,759
# アラフは日差しが見たい 春の風にあたりたい
# 00:00:06,759 --> 00:00:16,320
# アイスクリームが食べたい アラフは四季折々を平等に見ることもできなければ
# 00:00:16,320 --> 00:00:23,879
# 人間の一人一人に対しても 平等に見ることができないの
# ./srt/Haliva/Haliva_sleep1_Segment_22.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_23.wav 识别中...
# 0.94 seconds
# 00:00:00,000 --> 00:00:08,000
# だって、アラフの世界には、一人だけ特別な人がいるんだもの。
# ./srt/Haliva/Haliva_sleep1_Segment_23.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_24.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:12,000
# でもね、アラフ突然わかるようになったの。 アラフがこうなったのは、主に出会えたから。
# ./srt/Haliva/Haliva_sleep1_Segment_24.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_25.wav 识别中...
# 1.65 seconds
# 00:00:00,000 --> 00:00:11,000
# 主と一緒にいられたから、アラフはアイスクリームの味がわかったし、春の日差しと風も楽しみになったの。
# ./srt/Haliva/Haliva_sleep1_Segment_25.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_26.wav 识别中...
# 1.62 seconds
# 00:00:00,000 --> 00:00:06,879
# アラフが春を期待して アイスクリームが食べたいと思っているのは
# 00:00:06,879 --> 00:00:13,599
# すべて アラフが主のことを愛しているからなの
# ./srt/Haliva/Haliva_sleep1_Segment_26.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_27.wav 识别中...
# 1.43 seconds
# 00:00:00,000 --> 00:00:12,000
# 最初にアラフに、春はいつか来る、そして夏はアイスクリームの味だって教えてくれたのは、主だから。
# ./srt/Haliva/Haliva_sleep1_Segment_27.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_28.wav 识别中...
# 0.64 seconds
# 00:00:00,000 --> 00:00:05,000
# その全部、愛という言葉で表せるの
# ./srt/Haliva/Haliva_sleep1_Segment_28.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_29.wav 识别中...
# 0.89 seconds
# 00:00:00,000 --> 00:00:07,160
# アイスクリームが食べたい一心でこんなこと言ってるわけじゃないの
# ./srt/Haliva/Haliva_sleep1_Segment_29.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_3.wav 识别中...
# 1.37 seconds
# 00:00:00,000 --> 00:00:04,000
# 子供は寝ないと背が伸びなくなるの?
# 00:00:05,000 --> 00:00:11,000
# ふぅ…だって、今まだ眠くないもん。
# ./srt/Haliva/Haliva_sleep1_Segment_3.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_30.wav 识别中...
# 1.43 seconds
# 00:00:00,000 --> 00:00:03,000
# 違う…はず?
# 00:00:04,000 --> 00:00:08,000
# もう?きっと違うの
# 00:00:09,000 --> 00:00:15,000
# アイスクリームが主より大事なんてことあるはずがないもん
# ./srt/Haliva/Haliva_sleep1_Segment_30.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_31.wav 识别中...
# 1.54 seconds
# 00:00:00,000 --> 00:00:17,000
# もしアラフが主にこれ以上アイスクリームを食べちゃダメって言われたら…アラフは…アラフは…アラフは…
# ./srt/Haliva/Haliva_sleep1_Segment_31.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_32.wav 识别中...
# 0.80 seconds
# 00:00:00,000 --> 00:00:05,000
# うぅ……アラフはもう食べるのやめろから!
# ./srt/Haliva/Haliva_sleep1_Segment_32.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_33.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:03,640
# そんな意地悪しない?
# 00:00:03,640 --> 00:00:10,439
# えへへ、それぐらいアラフにだってわかるもん
# ./srt/Haliva/Haliva_sleep1_Segment_33.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_34.wav 识别中...
# 1.01 seconds
# 00:00:00,000 --> 00:00:09,839
# 主大好き 主はアラフの愛するアイスクリームの神様なの
# ./srt/Haliva/Haliva_sleep1_Segment_34.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_35.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:12,000
# あ、うっかり正解を言っちゃった。アラフがなんて書いたか、主に当ててもらいたかったのに。
# ./srt/Haliva/Haliva_sleep1_Segment_35.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_36.wav 识别中...
# 1.18 seconds
# 00:00:00,000 --> 00:00:04,000
# えっ?アラフの字がわからない?
# 00:00:05,000 --> 00:00:10,000
# そんなまさか…書き間違えるはずないのに…
# ./srt/Haliva/Haliva_sleep1_Segment_36.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_37.wav 识别中...
# 1.23 seconds
# 00:00:00,000 --> 00:00:10,000
# だって練習帳にもあったよ?粉字が書けるようになるまでアラフいっぱい練習したのに
# ./srt/Haliva/Haliva_sleep1_Segment_37.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_38.wav 识别中...
# 1.06 seconds
# 00:00:00,000 --> 00:00:05,000
# 練習帳に書かれた文字自体間違っているの?
# 00:00:06,000 --> 00:00:09,000
# そ、そんなぁ…
# ./srt/Haliva/Haliva_sleep1_Segment_38.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_39.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:12,000
# 大丈夫、まだ本があるよ。絵本にもこの字が出てきたの。そっちの方はきっと正しいはず。
# ./srt/Haliva/Haliva_sleep1_Segment_39.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_4.wav 识别中...
# 2.05 seconds
# 00:00:00,000 --> 00:00:15,000
# それにアラフが冬眠から目覚めてもうずいぶん経っているのに、背はちっとも伸びていないんだもん。アラフを寝させようとしても無駄なんだから。
# ./srt/Haliva/Haliva_sleep1_Segment_4.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_40.wav 识别中...
# 0.81 seconds
# 00:00:00,000 --> 00:00:05,000
# 探しに行かなくても、主が教えてくれるの?
# ./srt/Haliva/Haliva_sleep1_Segment_40.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_41.wav 识别中...
# 1.25 seconds
# 00:00:00,000 --> 00:00:09,279
# うん、わかった。愛を教えてくれた主に、愛という字の書き方を教わるの。
# 00:00:09,279 --> 00:00:11,279
# えへへへ
# ./srt/Haliva/Haliva_sleep1_Segment_41.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_42.wav 识别中...
# 0.90 seconds
# 00:00:00,000 --> 00:00:08,000
# えっ? 練習帳にじゃなくてアラフの背中に書くの?
# ./srt/Haliva/Haliva_sleep1_Segment_42.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_43.wav 识别中...
# 0.83 seconds
# 00:00:00,000 --> 00:00:07,320
# それじゃあラフ見えないよ また間違えちゃったらどうしよう
# ./srt/Haliva/Haliva_sleep1_Segment_43.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_44.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:06,000
# アラフが書けるようになるまでずっと教え続けてくれる?
# 00:00:07,000 --> 00:00:10,000
# えへへ、わかった。
# ./srt/Haliva/Haliva_sleep1_Segment_44.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_45.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:03,000
# はぁ…はぁ…
# 00:00:04,000 --> 00:00:07,000
# うん、アラフ準備できた。
# 00:00:08,000 --> 00:00:11,000
# 主、もう始めてもいいよ。
# ./srt/Haliva/Haliva_sleep1_Segment_45.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_46.wav 识别中...
# 0.81 seconds
# 00:00:00,000 --> 00:00:06,000
# ふふふ…くすぐったいよ…くすぐられているみたい…
# ./srt/Haliva/Haliva_sleep1_Segment_46.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_47.wav 识别中...
# 1.01 seconds
# 00:00:00,000 --> 00:00:09,000
# だめだめ、ハラフ動いちゃだめだから…でもくすぐったいや、うふふふふ
# ./srt/Haliva/Haliva_sleep1_Segment_47.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_48.wav 识别中...
# 0.99 seconds
# 00:00:00,000 --> 00:00:03,000
# あ、終わった
# 00:00:03,000 --> 00:00:06,000
# アラフ、分かったの
# 00:00:06,000 --> 00:00:10,000
# 今のは最後の一画だって
# ./srt/Haliva/Haliva_sleep1_Segment_48.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_49.wav 识别中...
# 1.90 seconds
# 00:00:00,000 --> 00:00:07,200
# ううう…じゃあアラフ、自分の手のひらで書いてみる
# 00:00:07,200 --> 00:00:17,080
# うふふふ、主に背中で字を書かれたせいで、手のひらまでくすぐったくなってきたの
# ./srt/Haliva/Haliva_sleep1_Segment_49.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_5.wav 识别中...
# 1.27 seconds
# 00:00:00,000 --> 00:00:05,000
# 主だって今すぐ寝られるって感じでもないし
# 00:00:05,000 --> 00:00:09,000
# もうちょっとアラフと遊んでいようよ
# 00:00:09,000 --> 00:00:11,000
# ゲームしよ
# ./srt/Haliva/Haliva_sleep1_Segment_5.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_50.wav 识别中...
# 1.05 seconds
# 00:00:00,000 --> 00:00:12,000
# 最初はこう…次はこう…次はこう描いて…違う、こうだっけ…違う違う…
# ./srt/Haliva/Haliva_sleep1_Segment_50.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_51.wav 识别中...
# 1.54 seconds
# 00:00:00,000 --> 00:00:08,000
# さっきアラフが書いた字と全く変わんない まだ間違ったまま
# 00:00:08,000 --> 00:00:13,519
# ひょっとしてアラフってアホの子なの?
# ./srt/Haliva/Haliva_sleep1_Segment_51.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_52.wav 识别中...
# 0.92 seconds
# 00:00:00,000 --> 00:00:08,000
# ちょっとドン臭いだけ。じゃあ主、もっかい書いてもらっていい?
# ./srt/Haliva/Haliva_sleep1_Segment_52.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_53.wav 识别中...
# 0.95 seconds
# 00:00:00,000 --> 00:00:07,000
# 今度こそ、アロフは絶対に笑わない。動かないから。
# ./srt/Haliva/Haliva_sleep1_Segment_53.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_54.wav 识别中...
# 1.91 seconds
# 00:00:00,000 --> 00:00:07,000
# はぁ…はぁ…はぁ…
# 00:00:07,000 --> 00:00:21,000
# うぅ…だめ…まだちょっと…主の指先がアラフの背中をなぞるのを考えただけで…くすぐったくなってきた…
# ./srt/Haliva/Haliva_sleep1_Segment_54.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_55.wav 识别中...
# 1.20 seconds
# 00:00:00,000 --> 00:00:03,000
# もうちょっと練習させて
# 00:00:03,000 --> 00:00:07,000
# えっ?今日はもう終わり?
# 00:00:07,000 --> 00:00:11,000
# アラフまだ全然覚えてないのに
# ./srt/Haliva/Haliva_sleep1_Segment_55.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_56.wav 识别中...
# 1.20 seconds
# 00:00:00,000 --> 00:00:02,720
# また明日教えてくれる?
# 00:00:04,040 --> 00:00:06,820
# うん、うん、わかった
# 00:00:06,820 --> 00:00:10,560
# アラフ、明日も勉強するから
# ./srt/Haliva/Haliva_sleep1_Segment_56.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_57.wav 识别中...
# 1.16 seconds
# 00:00:00,000 --> 00:00:10,720
# もしアラフがこのまま覚えられなくても それでも主はずっと教え続けてくれる?
# ./srt/Haliva/Haliva_sleep1_Segment_57.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_58.wav 识别中...
# 1.01 seconds
# 00:00:00,000 --> 00:00:10,000
# いひひ、主はきっとこの世で一番偉大な神様に違いないの
# ./srt/Haliva/Haliva_sleep1_Segment_58.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_59.wav 识别中...
# 2.11 seconds
# 00:00:00,000 --> 00:00:18,000
# アラフにアイスクリームを授けてくれて、アラフをぬくもりで包んでくれて、アラフに完全なる進化光を与えてくれて、そしてアラフに愛も授けてくれた。
# ./srt/Haliva/Haliva_sleep1_Segment_59.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_6.wav 识别中...
# 2.10 seconds
# 00:00:00,000 --> 00:00:03,000
# どんなゲームがいいかな?
# 00:00:03,000 --> 00:00:09,000
# あ、アラフはね、今いっぱい字が書けるようになったの。
# 00:00:09,000 --> 00:00:17,000
# 今から、主の背中に字を書いて、それが何の字か当てるゲームをしよう!
# ./srt/Haliva/Haliva_sleep1_Segment_6.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_60.wav 识别中...
# 1.22 seconds
# 00:00:00,000 --> 00:00:11,000
# 主、ずっとアラフの神様でいてほしいの。 アラフはこれからずっと主を愛しているから。
# ./srt/Haliva/Haliva_sleep1_Segment_60.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_7.wav 识别中...
# 1.25 seconds
# 00:00:00,000 --> 00:00:11,000
# いひひ、アラフは決めた。言いたかった内緒話を書こうってね。絶対当ててね。
# ./srt/Haliva/Haliva_sleep1_Segment_7.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_8.wav 识别中...
# 1.01 seconds
# 00:00:00,000 --> 00:00:07,000
# さあ、こっちに背中を向けて。アラフが最初の字を書くから。
# ./srt/Haliva/Haliva_sleep1_Segment_8.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep1_Segment_9.wav 识别中...
# 1.35 seconds
# 00:00:00,000 --> 00:00:04,000
# 主の背中って広いね。
# 00:00:04,000 --> 00:00:12,000
# この背中がアラフのために暖かい世界を支えてくれているのね。
# ./srt/Haliva/Haliva_sleep1_Segment_9.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_1.wav 识别中...
# 1.20 seconds
# 00:00:00,000 --> 00:00:03,480
# アラフは今日ちょっとだけ落ち込んでるの
# 00:00:04,560 --> 00:00:06,240
# ほんのちょっとだけ
# 00:00:07,240 --> 00:00:09,000
# 小指の爪ぐらい
# ./srt/Haliva/Haliva_sleep2_Segment_1.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_10.wav 识别中...
# 0.52 seconds
# 00:00:00,000 --> 00:00:04,000
# そのはずよね。そうよね。
# ./srt/Haliva/Haliva_sleep2_Segment_10.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_11.wav 识别中...
# 1.04 seconds
# 00:00:00,000 --> 00:00:08,000
# そ、それじゃあ、アラフはこれからアイスクリームを食べちゃダメなの?
# ./srt/Haliva/Haliva_sleep2_Segment_11.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_12.wav 识别中...
# 1.65 seconds
# 00:00:00,000 --> 00:00:04,000
# 嬉しければそれでいい?
# 00:00:04,000 --> 00:00:14,000
# うーん、アイスクリームを食べるのは嬉しいけど、大きくなれればもっと嬉しいの。
# ./srt/Haliva/Haliva_sleep2_Segment_12.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_13.wav 识别中...
# 1.08 seconds
# 00:00:00,000 --> 00:00:10,000
# もう…アラフ決めた。これから二度とアイスクリームを食べないようにする。
# ./srt/Haliva/Haliva_sleep2_Segment_13.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_14.wav 识别中...
# 1.48 seconds
# 00:00:00,000 --> 00:00:02,000
# それとは関係ない?
# 00:00:03,000 --> 00:00:05,000
# じゃあどうすれば…
# 00:00:06,000 --> 00:00:07,000
# ひょっとして…
# 00:00:08,000 --> 00:00:12,000
# アラフはこのままもう成長しないの?
# ./srt/Haliva/Haliva_sleep2_Segment_14.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_15.wav 识别中...
# 1.71 seconds
# 00:00:00,000 --> 00:00:04,879
# おかしいよ アラフは大人になれるもん
# 00:00:04,879 --> 00:00:15,000
# 春の神様みたいになれるはずなの だってこれまでのどの春の神様も大人になってるもん
# ./srt/Haliva/Haliva_sleep2_Segment_15.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_16.wav 识别中...
# 1.36 seconds
# 00:00:00,000 --> 00:00:02,000
# なんでなのかな?
# 00:00:03,500 --> 00:00:05,000
# はぁ…
# 00:00:05,500 --> 00:00:11,500
# なんで人間界で生きてるだけで、こんなにも悩ましくなるの?
# ./srt/Haliva/Haliva_sleep2_Segment_16.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_17.wav 识别中...
# 1.38 seconds
# 00:00:00,000 --> 00:00:12,080
# 人間たちもそうだったみたいだし 子供の頃は軟気で大人になるにつれて悩みが増えていく
# ./srt/Haliva/Haliva_sleep2_Segment_17.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_18.wav 识别中...
# 1.16 seconds
# 00:00:00,000 --> 00:00:08,000
# アラフはまだ大人になっていないはずなのに、なんでこんなに悩みが多いのかな?
# ./srt/Haliva/Haliva_sleep2_Segment_18.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_19.wav 识别中...
# 2.09 seconds
# 00:00:00,000 --> 00:00:05,120
# ん? アラフは今悩んでる
# 00:00:05,120 --> 00:00:20,080
# 人間は大きくなってから悩みが増えてくる それってひょっとして人間の尺度で言えばアラフはもう大人になったってこと?
# ./srt/Haliva/Haliva_sleep2_Segment_19.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_2.wav 识别中...
# 1.24 seconds
# 00:00:00,000 --> 00:00:12,000
# 主、アラフは今はもう愛の書き方を覚えたの。主に何度も教わったからね。
# ./srt/Haliva/Haliva_sleep2_Segment_2.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_20.wav 识别中...
# 1.39 seconds
# 00:00:00,000 --> 00:00:03,800
# そうよそうよ きっとそうよ
# 00:00:03,800 --> 00:00:07,799
# なんだ もう大人になってるのか
# 00:00:07,799 --> 00:00:11,800
# あらふったらトンくさいんだから えへへ
# ./srt/Haliva/Haliva_sleep2_Segment_20.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_21.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:10,880
# そういうことならアラフはもう悩まない 爪の先ぐらいの落ち込む気持ちもなくなったの
# ./srt/Haliva/Haliva_sleep2_Segment_21.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_22.wav 识别中...
# 0.96 seconds
# 00:00:00,000 --> 00:00:06,000
# アラフが微笑んでくれているのは、アラフが大人になったから?
# ./srt/Haliva/Haliva_sleep2_Segment_22.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_23.wav 识别中...
# 0.61 seconds
# 00:00:00,000 --> 00:00:05,600
# じゃあ 主はいつ大人になったの?
# ./srt/Haliva/Haliva_sleep2_Segment_23.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_24.wav 识别中...
# 1.16 seconds
# 00:00:00,000 --> 00:00:09,000
# ずっと前に、あの小さな村で主と出会う前に主はもう大人になってたでしょ?
# ./srt/Haliva/Haliva_sleep2_Segment_24.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_25.wav 识别中...
# 2.64 seconds
# 00:00:00,000 --> 00:00:08,000
# ということは、主はもう大人になってから長い時間が経っているのね
# 00:00:08,000 --> 00:00:17,000
# ふぅ、今先大人になったばかりのアラフですら悩みでいっぱいだから
# 00:00:17,000 --> 00:00:24,000
# もっと大人の主なら、もっとたくさんの悩みを抱えているはずなの
# ./srt/Haliva/Haliva_sleep2_Segment_25.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_26.wav 识别中...
# 0.91 seconds
# 00:00:00,000 --> 00:00:06,000
# もし悩みを抱えているのなら、必ずアラフにも教えて。
# ./srt/Haliva/Haliva_sleep2_Segment_26.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_27.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:10,240
# だってもうアラフは大人になったから 主の分まで背負ってあげることぐらいできるようになったの
# ./srt/Haliva/Haliva_sleep2_Segment_27.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_28.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:12,000
# いひひ、なんだかアラフ、今とっても誇らしい。大人になって、主の右腕になれるの。
# ./srt/Haliva/Haliva_sleep2_Segment_28.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_29.wav 识别中...
# 1.13 seconds
# 00:00:00,000 --> 00:00:09,000
# 主、これからアラフはもっともっと強くなって、史上最強の神様になるの。
# ./srt/Haliva/Haliva_sleep2_Segment_29.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_3.wav 识别中...
# 1.43 seconds
# 00:00:00,000 --> 00:00:05,000
# でも、こんな複雑な文字も書けるようになったのに。
# 00:00:06,000 --> 00:00:10,000
# なんでアラフはまだ子供のままなの?
# ./srt/Haliva/Haliva_sleep2_Segment_3.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_30.wav 识别中...
# 1.34 seconds
# 00:00:00,000 --> 00:00:14,679
# 主、まだ覚えてる? ずっと昔、魔女教会にいた時、アラフが主の願いを聞いた時のこと。
# ./srt/Haliva/Haliva_sleep2_Segment_30.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_31.wav 识别中...
# 1.34 seconds
# 00:00:00,000 --> 00:00:13,439
# あの時のアラフはまだ力が弱かったから 花一本や果物一個分くらいしか叶えてあげられなかったけど
# ./srt/Haliva/Haliva_sleep2_Segment_31.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_32.wav 识别中...
# 1.37 seconds
# 00:00:00,000 --> 00:00:03,000
# でも、今は違うの。
# 00:00:04,000 --> 00:00:11,000
# それよりもずっと複雑なことが、今のアラフならできるようになったの。
# ./srt/Haliva/Haliva_sleep2_Segment_32.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_33.wav 识别中...
# 1.09 seconds
# 00:00:00,000 --> 00:00:05,000
# 主の抱えてきた願いは、まだ叶ってないでしょ?
# 00:00:06,000 --> 00:00:08,000
# 今なら叶えてあげられる。
# ./srt/Haliva/Haliva_sleep2_Segment_33.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_34.wav 识别中...
# 1.55 seconds
# 00:00:00,000 --> 00:00:09,000
# 今はさすがに美少女に出会いたいなぁみたいな願い事じゃなくなってると思うし
# 00:00:09,000 --> 00:00:14,919
# だって 主はその辺物足りてるもの
# ./srt/Haliva/Haliva_sleep2_Segment_34.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_35.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:13,000
# それに、もし本当に主がまだそんな願い事をしたとしても、アラフとしてはそれが現実になってほしくないの。
# ./srt/Haliva/Haliva_sleep2_Segment_35.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_36.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:11,000
# おかしいの 主の願いならアラフは絶対に頑張って叶えてあげようとするはずなのに
# ./srt/Haliva/Haliva_sleep2_Segment_36.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_37.wav 识别中...
# 0.74 seconds
# 00:00:00,000 --> 00:00:05,000
# それとも、まだ今は叶えない方がいいかな?
# ./srt/Haliva/Haliva_sleep2_Segment_37.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_38.wav 识别中...
# 1.23 seconds
# 00:00:00,000 --> 00:00:10,000
# だってアラフは今大人になったばかりだし、これからもまだまだ成長の余地があるし。
# ./srt/Haliva/Haliva_sleep2_Segment_38.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_39.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:10,000
# アラフがアラフを生んだ春の神様みたいになったら、きっとどんなすごい願いだって叶えられるの。
# ./srt/Haliva/Haliva_sleep2_Segment_39.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_4.wav 识别中...
# 1.22 seconds
# 00:00:00,000 --> 00:00:09,000
# さっきドアの前に立って身長を測ってみたけど、ここに来た時と変わんないの。
# ./srt/Haliva/Haliva_sleep2_Segment_4.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_40.wav 识别中...
# 1.37 seconds
# 00:00:00,000 --> 00:00:11,000
# その時になったら、たとえ主が世界丸ごと欲しいと思っても、アラフは叶えてあげられるかも。
# ./srt/Haliva/Haliva_sleep2_Segment_40.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_41.wav 识别中...
# 1.62 seconds
# 00:00:00,000 --> 00:00:09,839
# 絵本の中に出てきた大きな願いを持ってる人間は世界丸ごと欲しいと言っていたの。
# 00:00:09,839 --> 00:00:13,839
# 主も欲しくなっちゃうの?
# ./srt/Haliva/Haliva_sleep2_Segment_41.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_42.wav 识别中...
# 2.00 seconds
# 00:00:00,000 --> 00:00:02,000
# 興味ない?
# 00:00:02,800 --> 00:00:05,600
# えへへ、ならいいの
# 00:00:06,400 --> 00:00:08,400
# 世界が欲しいなんていう
# 00:00:08,700 --> 00:00:12,700
# 絵本の中の人間はもっぱら大悪党で
# 00:00:13,200 --> 00:00:15,800
# 最後はやっつけられるオチだから
# ./srt/Haliva/Haliva_sleep2_Segment_42.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_43.wav 识别中...
# 2.46 seconds
# 00:00:00,000 --> 00:00:10,000
# アラフもたとえ本当に世界が手に入ったとしても、何に使うのかさっぱりわかんないし。
# 00:00:10,000 --> 00:00:17,000
# だってアラフの願いは、ただ主のそばにいたいだけ。
# 00:00:17,000 --> 00:00:23,000
# それは世界なんかよりも、ずっと大事なことだから。
# ./srt/Haliva/Haliva_sleep2_Segment_43.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_44.wav 识别中...
# 1.07 seconds
# 00:00:00,000 --> 00:00:08,000
# もしかして、主の願いも、アラフにずっと側にいてほしい、とかなの?
# ./srt/Haliva/Haliva_sleep2_Segment_44.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_45.wav 识别中...
# 0.71 seconds
# 00:00:00,000 --> 00:00:05,000
# それなら、願わなくても実現できるの。
# ./srt/Haliva/Haliva_sleep2_Segment_45.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_46.wav 识别中...
# 1.41 seconds
# 00:00:00,000 --> 00:00:04,000
# だってアラフはずっと主のそばにいるから
# 00:00:05,000 --> 00:00:11,000
# 主がどこにいてもアラフはちゃんとそばにずっといるから
# ./srt/Haliva/Haliva_sleep2_Segment_46.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_47.wav 识别中...
# 1.50 seconds
# 00:00:00,000 --> 00:00:10,599
# そして、主と一緒にたくさんのアイスクリームを食べて、一緒にいろんな春の景色を楽しむの。
# ./srt/Haliva/Haliva_sleep2_Segment_47.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_48.wav 识别中...
# 1.14 seconds
# 00:00:00,000 --> 00:00:10,000
# えへへ。なんだかアラフ、今、心の中がとっても忠実している気がする。
# ./srt/Haliva/Haliva_sleep2_Segment_48.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_49.wav 识别中...
# 1.89 seconds
# 00:00:00,000 --> 00:00:15,280
# 歴代の春の神様はみんな長い寿命を持っているけど、アラフが受け継いだ記憶の中には誰もこんな気持ちを抱いたことがなかったの。
# ./srt/Haliva/Haliva_sleep2_Segment_49.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_5.wav 识别中...
# 1.62 seconds
# 00:00:00,000 --> 00:00:07,000
# この枕も、立たせたらちょうど座っている時のアラフと同じ高さ。
# 00:00:08,000 --> 00:00:11,000
# これも最初とあんまり変わってないや。
# ./srt/Haliva/Haliva_sleep2_Segment_5.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_50.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:04,000
# これが幸せという感情なのね。
# 00:00:04,000 --> 00:00:10,000
# たくさん絵本を読んでいるから、その中で見たことあるの。
# ./srt/Haliva/Haliva_sleep2_Segment_50.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_51.wav 识别中...
# 1.12 seconds
# 00:00:00,000 --> 00:00:07,000
# 主の傍に居続けるだけで、アラフはそんな気持ちに満たされていく。
# ./srt/Haliva/Haliva_sleep2_Segment_51.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_52.wav 识别中...
# 1.33 seconds
# 00:00:00,000 --> 00:00:14,000
# あ、そんなことになったらアラフはもう悩みがなくなっちゃうの。まさかこれ以上もう大人になれないのかな。
# ./srt/Haliva/Haliva_sleep2_Segment_52.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_53.wav 识别中...
# 1.19 seconds
# 00:00:00,000 --> 00:00:07,000
# なんで笑ってるの?主、何が面白いの?
# 00:00:07,000 --> 00:00:12,599
# それともアラフ何かおかしかったの?
# ./srt/Haliva/Haliva_sleep2_Segment_53.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_54.wav 识别中...
# 1.93 seconds
# 00:00:00,000 --> 00:00:16,000
# えへへ。アラフはなんだかこのまま主の傍にいられて、主の笑顔を見られれば、たとえ大人にならなくても良くなってきた気がするの。
# ./srt/Haliva/Haliva_sleep2_Segment_54.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_55.wav 识别中...
# 0.92 seconds
# 00:00:00,000 --> 00:00:08,000
# 主のそばなら、可愛い子供のままでも十分幸せなんだから。
# ./srt/Haliva/Haliva_sleep2_Segment_55.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_56.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:08,000
# もちろん、背がちっちゃくても、主と悩みを分かち合うことぐらい、造作もないの。
# ./srt/Haliva/Haliva_sleep2_Segment_56.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_57.wav 识别中...
# 1.86 seconds
# 00:00:00,000 --> 00:00:17,000
# アラフは主のことが大好きなの。その気持ちがあれば、たとえちっちゃくてもすごい力を発揮できるの。主のためなら、何だってできるから。
# ./srt/Haliva/Haliva_sleep2_Segment_57.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_58.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:10,000
# 証明してあげたっていいの アラフは今、主のために何かしてあげるの
# ./srt/Haliva/Haliva_sleep2_Segment_58.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_59.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:11,000
# うん、わかったの。今夜寝るときはこのアラフが主のために布団をかけてあげるの。
# ./srt/Haliva/Haliva_sleep2_Segment_59.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_6.wav 识别中...
# 1.58 seconds
# 00:00:00,000 --> 00:00:03,000
# 牛乳だっていっぱい飲んだのに。
# 00:00:04,000 --> 00:00:10,000
# だって、牛乳は一番栄養価が高いんだってよく言うでしょ?
# ./srt/Haliva/Haliva_sleep2_Segment_6.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_60.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:10,000
# これまでは主が布団をかけてくれたけど、今日大人になったアラフにその任務をお任せください。
# ./srt/Haliva/Haliva_sleep2_Segment_60.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Smile.wav 识别中...
# 21.37 seconds
# 00:00:00,000 --> 00:00:01,500
# うぅぅぅぅぅぅぅぅぅっ
# ./srt/Haliva/Haliva_Smile.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_61.wav 识别中...
# 1.47 seconds
# 00:00:00,000 --> 00:00:04,000
# いい子にして、ちゃんと横になってね。
# 00:00:05,000 --> 00:00:11,000
# 手は体の両脇に置いて、布団の外に出しちゃダメだからね。
# ./srt/Haliva/Haliva_sleep2_Segment_61.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_62.wav 识别中...
# 1.41 seconds
# 00:00:00,000 --> 00:00:06,000
# 布団をかけてくれたときに主が言ってくれた言葉だよ。
# 00:00:06,000 --> 00:00:11,000
# 全部覚えているの。アラフすごいでしょ。
# ./srt/Haliva/Haliva_sleep2_Segment_62.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_63.wav 识别中...
# 0.98 seconds
# 00:00:00,000 --> 00:00:06,000
# さあ、目を閉じて。隙間がないかチェックしてあげる。
# ./srt/Haliva/Haliva_sleep2_Segment_63.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_64.wav 识别中...
# 1.25 seconds
# 00:00:00,000 --> 00:00:05,000
# 明かりも消すけど、一個だけ残してあげるの。
# 00:00:05,000 --> 00:00:08,000
# 真っ黒にならずに済むから。
# ./srt/Haliva/Haliva_sleep2_Segment_64.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_65.wav 识别中...
# 1.34 seconds
# 00:00:00,000 --> 00:00:05,000
# 怖くなったらいつでもアラフのこと呼んでいいよ。
# 00:00:05,000 --> 00:00:10,000
# アラフはちゃんと主のそばで寝ているから。
# ./srt/Haliva/Haliva_sleep2_Segment_65.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_66.wav 识别中...
# 1.20 seconds
# 00:00:00,000 --> 00:00:04,000
# はい、これで安心して寝られるね
# 00:00:04,000 --> 00:00:10,000
# あ、うっかり一番大事なことを忘れるところだった
# ./srt/Haliva/Haliva_sleep2_Segment_66.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_67.wav 识别中...
# 1.46 seconds
# 00:00:00,000 --> 00:00:08,000
# 毎日お休みするときにもらっている この世で一番大切なプレゼント
# 00:00:08,000 --> 00:00:11,000
# 今日はアラフが贈る番だよ
# ./srt/Haliva/Haliva_sleep2_Segment_67.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_68.wav 识别中...
# 0.62 seconds
# 00:00:00,000 --> 00:00:05,000
# おやすみ、アラフの愛しい主
# ./srt/Haliva/Haliva_sleep2_Segment_68.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_7.wav 识别中...
# 1.17 seconds
# 00:00:00,000 --> 00:00:06,000
# ミルクアイスは牛乳を飲んだことにならないのはなんで?
# 00:00:06,000 --> 00:00:09,000
# そんなのありえないよ
# ./srt/Haliva/Haliva_sleep2_Segment_7.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_8.wav 识别中...
# 1.53 seconds
# 00:00:00,000 --> 00:00:12,000
# アラフ見たの。主がアイスクリームを作ってる時、いっぱいミルク入れてるよ。コップいっぱい分もあったよ。
# ./srt/Haliva/Haliva_sleep2_Segment_8.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_sleep2_Segment_9.wav 识别中...
# 1.68 seconds
# 00:00:00,000 --> 00:00:11,000
# だからアラフがアイスクリームを一個食べるたびに牛乳を一杯飲んだことになるから、栄養はたっぷりとってるはず。
# ./srt/Haliva/Haliva_sleep2_Segment_9.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_SpringFestival_Gift_01.wav 识别中...
# 2.39 seconds
# 00:00:00,000 --> 00:00:03,200
# 春を迎えるためのプレゼント?
# 00:00:04,040 --> 00:00:05,000
# えへへ…
# 00:00:05,440 --> 00:00:08,000
# アラフ何も準備してないよ!
# 00:00:08,359 --> 00:00:09,400
# どうしよう…
# 00:00:10,120 --> 00:00:11,599
# 笑えばいい?
# 00:00:12,240 --> 00:00:12,839
# え…
# 00:00:13,720 --> 00:00:14,759
# えへへ…
# 00:00:15,040 --> 00:00:18,480
# アラフ、主のことが大好きだよ!
# ./srt/Haliva/Haliva_SpringFestival_Gift_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_SpringFestival_Greet.wav 识别中...
# 1.50 seconds
# 00:00:00,000 --> 00:00:10,900
# この日が来たら、冬の雪が溶け始めて、そしてもうちょっとしたら春がやってくるんだっけ。
# 00:00:11,839 --> 00:00:13,839
# 素敵ねー。
# ./srt/Haliva/Haliva_SpringFestival_Greet.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Strike.wav 识别中...
# 0.82 seconds
# 00:00:00,000 --> 00:00:07,560
# 雪はいつか溶ける 冬だっていつか終わるから
# ./srt/Haliva/Haliva_Strike.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Striked.wav 识别中...
# 0.66 seconds
# 00:00:00,000 --> 00:00:03,600
# アラフの主を…いじめないで…
# ./srt/Haliva/Haliva_Striked.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Midnight_Greet_01.wav 识别中...
# 1.19 seconds
# 00:00:00,000 --> 00:00:03,160
# いつになったら夜が明けるの?
# 00:00:04,600 --> 00:00:06,600
# 東から光が?
# 00:00:08,199 --> 00:00:11,000
# お日様が昇ってくるのかな?
# ./srt/Haliva/Haliva_Sunny_Midnight_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Midnight_Greet_02.wav 识别中...
# 1.34 seconds
# 00:00:00,000 --> 00:00:04,000
# バージナーお姉ちゃんが夜食を作ってくれたよ
# 00:00:04,500 --> 00:00:05,500
# 今食べる?
# 00:00:06,000 --> 00:00:08,000
# アラフが持ってきてあげる
# ./srt/Haliva/Haliva_Sunny_Midnight_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Midnight_Greet_03.wav 识别中...
# 0.87 seconds
# 00:00:00,000 --> 00:00:07,679
# マイロード 寝る前にアラフのお話を聞かせて
# ./srt/Haliva/Haliva_Sunny_Midnight_Greet_03.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Morning_Greet_01.wav 识别中...
# 1.21 seconds
# 00:00:00,000 --> 00:00:03,839
# おはようおはよう これはねー
# 00:00:03,839 --> 00:00:09,080
# アラフが新しく覚えた挨拶の言葉だよ
# ./srt/Haliva/Haliva_Sunny_Morning_Greet_01.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Morning_Greet_02.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:02,000
# くんくん
# 00:00:02,000 --> 00:00:04,000
# ねぇ、主
# 00:00:04,000 --> 00:00:06,000
# 朝の空気って
# 00:00:06,000 --> 00:00:08,000
# なんだかいい香りがしない?
# ./srt/Haliva/Haliva_Sunny_Morning_Greet_02.srt 已保存 Saved
# ./raw_audio/Haliva/Haliva_Sunny_Morning_Greet_03.wav 识别中...
# 1.28 seconds
# 00:00:00,000 --> 00:00:04,679
# 今日のアラフはちょっと背が伸びたかなぁ
# 00:00:04,679 --> 00:00:06,200
# あれ?
# 00:00:06,200 --> 00:00:11,080
# ここらへん葉っぱが増えてるみたい
# ./srt/Haliva/Haliva_Sunny_Morning_Greet_03.srt 已保存 Saved
# ...
# 00:00:00,000 --> 00:00:06,000
# それでも、私は先輩のこと諦めたくない。
# 00:00:07,000 --> 00:00:12,000
# だって、私先輩のことが好きなんだもん。
# ./srt/QingHao/QingHao_sleep2_Segment_51.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_52.wav 识别中...
# 0.79 seconds
# 00:00:00,000 --> 00:00:04,000
# これは冗談でもからかいでもなく
# 00:00:04,000 --> 00:00:08,000
# 心からの気持ちよ
# ./srt/QingHao/QingHao_sleep2_Segment_52.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_53.wav 识别中...
# 0.76 seconds
# 00:00:00,000 --> 00:00:05,000
# 先輩、もう遅いから、そろそろ寝ましょう。
# ./srt/QingHao/QingHao_sleep2_Segment_53.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_54.wav 识别中...
# 1.68 seconds
# 00:00:00,000 --> 00:00:03,240
# ほらもちろん、あたしの部屋でね。
# 00:00:04,440 --> 00:00:09,800
# 先輩が来るのを想定して、快適な枕もちゃんと用意しておいたわよ。
# ./srt/QingHao/QingHao_sleep2_Segment_54.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_55.wav 识别中...
# 1.50 seconds
# 00:00:00,000 --> 00:00:04,000
# ベッドは増やさないのかって?
# 00:00:04,000 --> 00:00:10,000
# ベッドを増やすよりも、私がそばにいて寝たほうがいいでしょ?
# ./srt/QingHao/QingHao_sleep2_Segment_55.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_56.wav 识别中...
# 1.09 seconds
# 00:00:00,000 --> 00:00:04,560
# じゃあじゃあ お互いの目を見つめ合って
# 00:00:04,560 --> 00:00:09,560
# 指を絡め合ってお休みしましょうか
# ./srt/QingHao/QingHao_sleep2_Segment_56.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_57.wav 识别中...
# 0.87 seconds
# 00:00:00,000 --> 00:00:07,000
# ねえ、眠りにつく前にもう少しおしゃべりしない?
# ./srt/QingHao/QingHao_sleep2_Segment_57.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_58.wav 识别中...
# 0.70 seconds
# 00:00:00,000 --> 00:00:02,000
# 先輩?
# 00:00:02,000 --> 00:00:04,000
# まさかもう眠ったの?
# ./srt/QingHao/QingHao_sleep2_Segment_58.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_59.wav 识别中...
# 1.55 seconds
# 00:00:00,000 --> 00:00:02,000
# 先輩?
# 00:00:02,000 --> 00:00:04,000
# 先輩?
# 00:00:04,000 --> 00:00:06,000
# 早く起きて?
# 00:00:07,000 --> 00:00:12,000
# ねえ、かわいい後輩が話しかけてるわよ。
# 00:00:12,000 --> 00:00:14,000
# 先輩?
# ./srt/QingHao/QingHao_sleep2_Segment_59.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_6.wav 识别中...
# 0.95 seconds
# 00:00:00,000 --> 00:00:09,000
# えっ? 光剣ではなく、大剣を使うべきところなのでは…と。
# ./srt/QingHao/QingHao_sleep2_Segment_6.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_60.wav 识别中...
# 0.49 seconds
# 00:00:00,000 --> 00:00:03,000
# あら、起きないわね
# ./srt/QingHao/QingHao_sleep2_Segment_60.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_61.wav 识别中...
# 1.81 seconds
# 00:00:00,000 --> 00:00:20,000
# うむ。なんか怪しいわね。先輩、ネタフリでもしてるのかしら。からかわれるのが怖くて。それか、もしかしてからかわれるのを期待してる?
# ./srt/QingHao/QingHao_sleep2_Segment_61.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_62.wav 识别中...
# 0.92 seconds
# 00:00:00,000 --> 00:00:06,000
# まぁいっか、どちらにせよ。今日はこれくらいにしてあげるわ。
# ./srt/QingHao/QingHao_sleep2_Segment_62.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_63.wav 识别中...
# 1.07 seconds
# 00:00:00,000 --> 00:00:05,000
# 先輩だって疲れているでしょうから
# 00:00:05,000 --> 00:00:10,000
# それなら、私も早く寝ちゃおうかしら
# ./srt/QingHao/QingHao_sleep2_Segment_63.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_64.wav 识别中...
# 0.88 seconds
# 00:00:00,000 --> 00:00:08,240
# 先輩 私が眠りについても逃げちゃダメだからね
# ./srt/QingHao/QingHao_sleep2_Segment_64.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_65.wav 识别中...
# 0.89 seconds
# 00:00:00,000 --> 00:00:02,000
# ……
# 00:00:05,000 --> 00:00:11,000
# 寝室のドアの前には、トラップがあるからね。
# ./srt/QingHao/QingHao_sleep2_Segment_65.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_66.wav 识别中...
# 0.76 seconds
# 00:00:00,000 --> 00:00:08,800
# …先輩…おやすみ…
# 00:00:08,800 --> 00:00:10,800
# …ふぅ…
# ./srt/QingHao/QingHao_sleep2_Segment_66.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_67.wav 识别中...
# 0.96 seconds
# 00:00:00,000 --> 00:00:09,000
# やっぱり先輩の寝顔を眺めるの本当に楽しいわね。
# ./srt/QingHao/QingHao_sleep2_Segment_67.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_68.wav 识别中...
# 0.89 seconds
# 00:00:00,000 --> 00:00:06,000
# 今晩は先輩を見つめたまま寝ようかしら。
# ./srt/QingHao/QingHao_sleep2_Segment_68.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_7.wav 识别中...
# 1.52 seconds
# 00:00:00,000 --> 00:00:05,000
# うん、ご指摘感謝する。いや、違う。
# 00:00:05,000 --> 00:00:12,000
# ああ、もう!これじゃ、私がお姉ちゃんのフリをしていることなんてもうバレバレじゃない!
# ./srt/QingHao/QingHao_sleep2_Segment_7.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_8.wav 识别中...
# 1.31 seconds
# 00:00:00,000 --> 00:00:09,000
# もう先輩ったら、せっかく私がこんなに面白いことを思いついたのに、あさり見破っちゃうなんて。
# ./srt/QingHao/QingHao_sleep2_Segment_8.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_sleep2_Segment_9.wav 识别中...
# 2.01 seconds
# 00:00:00,000 --> 00:00:03,000
# まあそれも仕方ないかしら。
# 00:00:04,000 --> 00:00:09,000
# なんせあたしはお姉ちゃんなんかよりもずっと可愛いんだもの。
# 00:00:09,000 --> 00:00:14,000
# やはり人の気品って簡単に隠し通せるものじゃないものね。
# ./srt/QingHao/QingHao_sleep2_Segment_9.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Smile_2.wav 识别中...
# 0.32 seconds
# 00:00:00,000 --> 00:00:02,000
# ふふふ
# ./srt/QingHao/QingHao_Smile_2.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_SpringFestival_Gift_01.wav 识别中...
# 0.95 seconds
# 00:00:00,000 --> 00:00:05,000
# 先輩明けおめー!お年玉もたくさんちょうだいねー!
# ./srt/QingHao/QingHao_SpringFestival_Gift_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_SpringFestival_Greet.wav 识别中...
# 1.14 seconds
# 00:00:00,000 --> 00:00:10,679
# 先輩新年あけおめ これからも元気で万事思い通りにたくさん儲かりますように
# ./srt/QingHao/QingHao_SpringFestival_Greet.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Strike.wav 识别中...
# 1.03 seconds
# 00:00:00,000 --> 00:00:05,000
# 痛い目に遭いたくなければ、おとなしく降参して謝罪なさい。
# ./srt/QingHao/QingHao_Strike.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Striked.wav 识别中...
# 0.80 seconds
# 00:00:00,000 --> 00:00:04,000
# 手を出すなら、土下座じゃ済まされないわよ
# ./srt/QingHao/QingHao_Striked.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Midnight_Greet_01.wav 识别中...
# 1.41 seconds
# 00:00:00,000 --> 00:00:10,240
# この時間にお化けに仮装して、こっそり先輩のお布団の中に隠れてみたら…面白そうね!
# ./srt/QingHao/QingHao_Sunny_Midnight_Greet_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Midnight_Greet_02.wav 识别中...
# 1.37 seconds
# 00:00:00,000 --> 00:00:05,960
# 眠いわぁ…先輩はまだ帰ってこないの?
# 00:00:05,960 --> 00:00:13,359
# このままだと私、見つかる前に眠っちゃいそう…
# ./srt/QingHao/QingHao_Sunny_Midnight_Greet_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Midnight_Greet_03.wav 识别中...
# 1.84 seconds
# 00:00:00,000 --> 00:00:05,200
# うわっ!やばっ!先輩の布団の中に隠れたまま寝落ちしてた!
# 00:00:05,200 --> 00:00:07,200
# 先輩は…
# 00:00:07,200 --> 00:00:11,200
# まさか、もう起きて部屋から出たの!?
# ./srt/QingHao/QingHao_Sunny_Midnight_Greet_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Morning_Greet_01.wav 识别中...
# 1.25 seconds
# 00:00:00,000 --> 00:00:03,760
# 先輩!可愛い後輩が起こしに来たわよ!
# 00:00:03,760 --> 00:00:05,759
# 寝坊は許さないんだから!
# ./srt/QingHao/QingHao_Sunny_Morning_Greet_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Morning_Greet_02.wav 识别中...
# 1.44 seconds
# 00:00:00,000 --> 00:00:08,339
# へへへん、朝食に気持ちが高ぶる冷蔵を混ぜれば、先輩も喜んでお小遣いをくれるはずー
# ./srt/QingHao/QingHao_Sunny_Morning_Greet_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Morning_Greet_03.wav 识别中...
# 1.52 seconds
# 00:00:00,000 --> 00:00:10,640
# たくさん寝たんだからそろそろ起きる頃よ 先輩私と面白いことを探しに一緒にお出かけしましょう
# ./srt/QingHao/QingHao_Sunny_Morning_Greet_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Noon_Greet_01.wav 识别中...
# 1.30 seconds
# 00:00:00,000 --> 00:00:04,600
# 北名に魚あり その名をコンとなす
# 00:00:04,600 --> 00:00:10,279
# コンの王位なるその肉鍋で煮れるのかを知らず
# ./srt/QingHao/QingHao_Sunny_Noon_Greet_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Noon_Greet_02.wav 识别中...
# 1.68 seconds
# 00:00:00,000 --> 00:00:04,000
# ご飯の時に基地にイノシシを放せば
# 00:00:04,000 --> 00:00:06,080
# あちこち駆け回っている隙に
# 00:00:06,080 --> 00:00:09,679
# 先輩のご飯を全部ごっそりいただけるかも
# ./srt/QingHao/QingHao_Sunny_Noon_Greet_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Noon_Greet_03.wav 识别中...
# 1.22 seconds
# 00:00:00,000 --> 00:00:07,000
# これ以上私をほっとくなら、先輩が仕事時間にサボってるって、教団にちくっちゃうわよ。
# ./srt/QingHao/QingHao_Sunny_Noon_Greet_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Weekend_Greet_01.wav 识别中...
# 1.63 seconds
# 00:00:00,000 --> 00:00:06,719
# 先輩 教団から休日残業の注意喚起の通知が来てるわよ
# 00:00:06,719 --> 00:00:11,279
# わざわざ早起きして知らせに来てあげたわ
# ./srt/QingHao/QingHao_Sunny_Weekend_Greet_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Weekend_Greet_02.wav 识别中...
# 1.59 seconds
# 00:00:00,000 --> 00:00:03,740
# 今度休日でみんなが遅くまで寝ている隙に
# 00:00:04,480 --> 00:00:06,280
# こっそり先輩の顔に
# 00:00:06,280 --> 00:00:08,679
# 豚ちゃんを描いてあげようかしら
# ./srt/QingHao/QingHao_Sunny_Weekend_Greet_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Sunny_Weekend_Greet_03.wav 识别中...
# 1.51 seconds
# 00:00:00,000 --> 00:00:11,720
# 何を隠そう? 五字波を立ち上げられたのはこの私に天才的な読解力と類稀なる知能が備わっていたからよ
# ./srt/QingHao/QingHao_Sunny_Weekend_Greet_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_titlecall.wav 识别中...
# 0.42 seconds
# 00:00:00,000 --> 00:00:02,000
# ソウルタイド
# ./srt/QingHao/QingHao_titlecall.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Breast_01.wav 识别中...
# 0.97 seconds
# 00:00:00,000 --> 00:00:05,759
# うわぁ!どこ触ってるのよ!一変痛い目に合わせようかしら
# ./srt/QingHao/QingHao_Touch_Breast_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Breast_02.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:10,200
# 司令見ることなかれ、司令聞くことなかれ、司令言うことなかれ、司令動くことなかれ。
# ./srt/QingHao/QingHao_Touch_Breast_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Breast_03.wav 识别中...
# 0.88 seconds
# 00:00:00,000 --> 00:00:07,759
# いつから先輩ではなく私がからかわれる側になったのかしら
# ./srt/QingHao/QingHao_Touch_Breast_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hand_01.wav 识别中...
# 0.76 seconds
# 00:00:00,000 --> 00:00:05,839
# ちょ、ちょっと!いきなりそんな…私、まだ心の準備が…
# ./srt/QingHao/QingHao_Touch_Hand_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hand_02.wav 识别中...
# 0.93 seconds
# 00:00:00,000 --> 00:00:04,879
# 手を繋ぐのはここでは普通の文化なの?
# 00:00:04,879 --> 00:00:09,200
# もうそれならいいけど
# ./srt/QingHao/QingHao_Touch_Hand_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hand_03.wav 识别中...
# 0.91 seconds
# 00:00:00,000 --> 00:00:05,719
# 先輩、ひょっとして今、私と手を繋ぎたいって思ってる?
# ./srt/QingHao/QingHao_Touch_Hand_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hand_04.wav 识别中...
# 1.38 seconds
# 00:00:00,000 --> 00:00:05,320
# しょうがない先輩ね 私が手を繋いであげなかったら
# 00:00:05,320 --> 00:00:10,560
# 今頃大泣きして大暴れしていたところね
# ./srt/QingHao/QingHao_Touch_Hand_04.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hand_05.wav 识别中...
# 1.46 seconds
# 00:00:00,000 --> 00:00:04,679
# 先輩 これは秘密なんだけど
# 00:00:04,679 --> 00:00:11,000
# 県令ってね 手を繋いだだけで結婚が成立しちゃうの
# 00:00:11,000 --> 00:00:13,800
# なんちゃって
# ./srt/QingHao/QingHao_Touch_Hand_05.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Head_01.wav 识别中...
# 0.75 seconds
# 00:00:00,000 --> 00:00:02,240
# せ、先輩?
# 00:00:02,879 --> 00:00:06,040
# え、今私に何かした?
# ./srt/QingHao/QingHao_Touch_Head_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Head_02.wav 识别中...
# 1.23 seconds
# 00:00:00,000 --> 00:00:09,160
# いくら先輩でも勝手に私の頭触っちゃダメよ 頭悪くなったらどうしてくれるのよ
# ./srt/QingHao/QingHao_Touch_Head_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Head_03.wav 识别中...
# 1.03 seconds
# 00:00:00,000 --> 00:00:02,439
# 先輩って変わってるわよね。
# 00:00:03,520 --> 00:00:06,560
# 私の髪にそんなに魅力があるわけ?
# ./srt/QingHao/QingHao_Touch_Head_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Head_04.wav 识别中...
# 1.29 seconds
# 00:00:00,000 --> 00:00:05,160
# ふふふ、ひょっとして先輩、私のこと好きになっちゃった?
# 00:00:06,040 --> 00:00:09,279
# そういうことなら、考えてあげなくもないわよ。
# ./srt/QingHao/QingHao_Touch_Head_04.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Head_05.wav 识别中...
# 1.10 seconds
# 00:00:00,000 --> 00:00:08,700
# 先輩が撫でていいのは、私の頭だけだから。もし姉にも同じことしてたら…
# ./srt/QingHao/QingHao_Touch_Head_05.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hip_01.wav 识别中...
# 0.90 seconds
# 00:00:00,000 --> 00:00:03,580
# この……ドヘンタイ!
# 00:00:03,580 --> 00:00:06,080
# この貢献を喰らいなさい!
# ./srt/QingHao/QingHao_Touch_Hip_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Hip_02.wav 识别中...
# 0.80 seconds
# 00:00:00,000 --> 00:00:03,520
# 先輩 約束よ
# 00:00:03,520 --> 00:00:08,439
# これから一生 私だけ見ていてね
# ./srt/QingHao/QingHao_Touch_Hip_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Locked.wav 识别中...
# 0.98 seconds
# 00:00:00,000 --> 00:00:07,839
# 何を言っても無駄よ 私の五次憲法の餌食になりなさい
# ./srt/QingHao/QingHao_Touch_Locked.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_01.wav 识别中...
# 1.04 seconds
# 00:00:00,000 --> 00:00:08,000
# 先輩、ずっと私と一緒にいたら他の子に嫉妬されちゃうわよ
# ./srt/QingHao/QingHao_Touch_Reaction_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_02.wav 识别中...
# 1.19 seconds
# 00:00:00,000 --> 00:00:08,400
# おかしいわね…別に優しくなる薬を持った記憶なんてないのに…なんでかしら?
# ./srt/QingHao/QingHao_Touch_Reaction_02.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_03.wav 识别中...
# 1.30 seconds
# 00:00:00,000 --> 00:00:04,000
# 先輩が今何考えてるのか当てていいかしら?
# 00:00:04,000 --> 00:00:06,000
# 正解だったらご褒美ちょうだい?
# ./srt/QingHao/QingHao_Touch_Reaction_03.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_04.wav 识别中...
# 1.03 seconds
# 00:00:00,000 --> 00:00:05,600
# 先輩、面白いこと考えたの。知りたければ、もっとこっちに来て。
# ./srt/QingHao/QingHao_Touch_Reaction_04.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_05.wav 识别中...
# 1.76 seconds
# 00:00:00,000 --> 00:00:04,620
# 仙人の修行は、由緒正しい門派の人じゃなくてもできるわよ。
# 00:00:05,620 --> 00:00:08,960
# たとえ戸敷でも、頑張れば仙人になれるわ。
# ./srt/QingHao/QingHao_Touch_Reaction_05.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_06.wav 识别中...
# 1.19 seconds
# 00:00:00,000 --> 00:00:07,520
# 権利の力がなくたって、私は自分の力で誰よりも高みへとたどり着けるわ。
# ./srt/QingHao/QingHao_Touch_Reaction_06.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_07.wav 识别中...
# 0.83 seconds
# 00:00:00,000 --> 00:00:05,000
# 今ちょっと気分が悪いの。また後で来てちょうだい。
# ./srt/QingHao/QingHao_Touch_Reaction_07.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_08.wav 识别中...
# 0.57 seconds
# 00:00:00,000 --> 00:00:04,000
# 先輩、今はちょっと一人にして
# ./srt/QingHao/QingHao_Touch_Reaction_08.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_09.wav 识别中...
# 0.66 seconds
# 00:00:00,000 --> 00:00:04,000
# 後輩からもっと厳しくされたいのね
# ./srt/QingHao/QingHao_Touch_Reaction_09.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_Birthday.wav 识别中...
# 1.65 seconds
# 00:00:00,000 --> 00:00:06,000
# 誕生日というものには、生きる者への祝福と期待が込められているわ。
# 00:00:07,400 --> 00:00:10,900
# いつどんな時でも希望を持っていてね、先輩。
# ./srt/QingHao/QingHao_Touch_Reaction_Birthday.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_Christmas.wav 识别中...
# 1.17 seconds
# 00:00:00,000 --> 00:00:07,759
# 一人でいるのには慣れてるけど 先輩と一緒に過ごすのも悪くないかも
# ./srt/QingHao/QingHao_Touch_Reaction_Christmas.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_Qixi.wav 识别中...
# 0.72 seconds
# 00:00:00,000 --> 00:00:07,400
# 先輩…姉に同じことしちゃダメだからね
# ./srt/QingHao/QingHao_Touch_Reaction_Qixi.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_SpringFestival.wav 识别中...
# 1.44 seconds
# 00:00:00,000 --> 00:00:03,080
# 先輩、一緒に水餃子を食べましょう
# 00:00:03,839 --> 00:00:09,080
# どれか一つに幸運をもたらす隠し味を入れておいたわよ
# ./srt/QingHao/QingHao_Touch_Reaction_SpringFestival.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Reaction_Valentine.wav 识别中...
# 1.15 seconds
# 00:00:00,000 --> 00:00:02,000
# 何も言わなくてもわかるわ。
# 00:00:03,200 --> 00:00:06,799
# 先輩の言いたいことは、全部お見通しよ。
# ./srt/QingHao/QingHao_Touch_Reaction_Valentine.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Touch_Unhappy.wav 识别中...
# 1.18 seconds
# 00:00:00,000 --> 00:00:05,160
# 先輩 全身山嵐の針に刺されたら
# 00:00:05,160 --> 00:00:08,599
# どんな感覚か知ってる?
# ./srt/QingHao/QingHao_Touch_Unhappy.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Unhappy_Greet.wav 识别中...
# 0.77 seconds
# 00:00:00,000 --> 00:00:06,679
# 顔色も伺えない人は誰にも愛されないわよ
# ./srt/QingHao/QingHao_Unhappy_Greet.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Valentine_Gift_01.wav 识别中...
# 1.09 seconds
# 00:00:00,000 --> 00:00:03,000
# このプレゼントは…その…
# 00:00:04,299 --> 00:00:08,500
# 先輩からの告白ってことで…いいわよね?
# ./srt/QingHao/QingHao_Valentine_Gift_01.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Valentine_Greet.wav 识别中...
# 1.35 seconds
# 00:00:00,000 --> 00:00:02,000
# バレンタインだよね
# 00:00:02,560 --> 00:00:04,139
# こんな日に
# 00:00:04,139 --> 00:00:06,140
# 先輩なら絶対私のこと
# 00:00:07,200 --> 00:00:09,759
# 一人にしないって信じてるわ
# ./srt/QingHao/QingHao_Valentine_Greet.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Wedding.wav 识别中...
# 3.10 seconds
# 00:00:00,000 --> 00:00:06,799
# 先輩って悪い人ね。 シレッと私のことを物にしちゃうなんて。
# 00:00:06,799 --> 00:00:15,519
# うーん、 制約における不正行為を教壇に作ったら面白いことになりそうね。
# 00:00:15,519 --> 00:00:26,359
# 安心なさい、そんなことしないわ。 ええ、これを出しにしてからかったりだなんて絶対にしないんだから。
# ./srt/QingHao/QingHao_Wedding.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Whisper_ClickOK.wav 识别中...
# 0.77 seconds
# 00:00:00,000 --> 00:00:06,000
# 取って食べたりしないわよ 安心して入ってきなさい
# ./srt/QingHao/QingHao_Whisper_ClickOK.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Whisper_OpenUI.wav 识别中...
# 1.15 seconds
# 00:00:00,000 --> 00:00:04,280
# 先輩、私に何か要かしら?
# 00:00:04,280 --> 00:00:10,400
# ひょっとして、私のこと恋しくなっちゃった?
# ./srt/QingHao/QingHao_Whisper_OpenUI.srt 已保存 Saved
# ./raw_audio/QingHao/QingHao_Win.wav 识别中...
# 0.87 seconds
# 00:00:00,000 --> 00:00:05,000
# 先輩、成功のこと、ちゃんと褒めてくれてもいいわよ
# ./srt/QingHao/QingHao_Win.srt 已保存 Saved
# 字幕生成完毕
